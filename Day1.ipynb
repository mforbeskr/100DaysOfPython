# %%
print("Hello " + input("What is your name?") + "!")
# Out:
# Hello uu!

# %%
print(len(input("Whats ur name")))
# Out:
# 3

# %%
username = input("What is your name")
length = len(username)
print(length)
# Out:
# 2

# %%
glass1 = "milk"
glass2 = "juice"
print(glass1, glass2)

glass3 = glass1
glass1 = glass2
glass2 = glass3
print(glass1, glass2)
# Out:
# milk juice
# juice milk

# %%
print("=== Welcome to the Band Name Generator. ===")
user_city = input("Which city did you grow up in?\n")
user_pet = input("Enter a pet name\n")
print("Your band name is: \n"+user_city, user_pet)
# Out:
# === Welcome to the Band Name Generator. ===
# Your band name is:
# uuu uu

# %%
print("Hello"[4])
# Out:
# o
